# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 44 kB 1.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 147 kB 9.8 MB/s
# ...
#   Created wheel for openai: filename=openai-0.25.0-py3-none-any.whl size=55880 sha256=14a55f29a808e25a0ae813fe6574ba8ef144945c1fbbc80d01d9ac1e5ec974ec
#   Stored in directory: /root/.cache/pip/wheels/4b/92/33/6f57c7aae0b16875267999a50570e81f15eecec577ebe05a2e
# Successfully built openai
# ...

# %%
import openai
import urllib.request
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow

# %%
openai.api_key = "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"

# %%
img_response = openai.Image.create(
    prompt = "an astronaut lounging in a tropical resort in space",
    n=1,
    size = "512x512"
)

# %%
img_response
# Out:
# <OpenAIObject at 0x7fac694aebd0> JSON: {
#   "created": 1671024646,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-YohzkOy44VLOdECXpzYR6O5i/user-xeLhsyEi9engOV3qQVMAnKdq/img-OwZK33yo6oJR3DvcI5Pfhw7t.png?st=2022-12-14T12%3A30%3A46Z&se=2022-12-14T14%3A30%3A46Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-14T10%3A44%3A13Z&ske=2022-12-15T10%3A44%3A13Z&sks=b&skv=2021-08-06&sig=7yu1%2Bz6O3GHJH2tbdv9rTnGGmAZXYqH6TFODamLMYyY%3D"
#     }
#   ]
# }

# %%
img_response['data'][0]['url']
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-YohzkOy44VLOdECXpzYR6O5i/user-xeLhsyEi9engOV3qQVMAnKdq/img-OwZK33yo6oJR3DvcI5Pfhw7t.png?st=2022-12-14T12%3A30%3A46Z&se=2022-12-14T14%3A30%3A46Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-14T10%3A44%3A13Z&ske=2022-12-15T10%3A44%3A13Z&sks=b&skv=2021-08-06&sig=7yu1%2Bz6O3GHJH2tbdv9rTnGGmAZXYqH6TFODamLMYyY%3D'

# %%
img_url = img_response['data'][0]['url']
img_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-YohzkOy44VLOdECXpzYR6O5i/user-xeLhsyEi9engOV3qQVMAnKdq/img-OwZK33yo6oJR3DvcI5Pfhw7t.png?st=2022-12-14T12%3A30%3A46Z&se=2022-12-14T14%3A30%3A46Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-14T10%3A44%3A13Z&ske=2022-12-15T10%3A44%3A13Z&sks=b&skv=2021-08-06&sig=7yu1%2Bz6O3GHJH2tbdv9rTnGGmAZXYqH6TFODamLMYyY%3D'

# %%
urllib.request.urlretrieve(img_url, 'img.png')
# Out:
# ('img.png', <http.client.HTTPMessage at 0x7fac5fb7f2b0>)

# %%
img=cv2.imread('img.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FAC694DE970>
